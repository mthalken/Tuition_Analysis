# %%
# Add dependencies
import pandas as pd
import numpy as np

# %%
# load files
cost_attendance_df = pd.read_csv("Resources/cost-attendance.csv")
financial_aid_df = pd.read_csv("Resources/financial-aid.csv")
grad_rates_df = pd.read_csv("Resources/grad-rates.csv")
institutions_df = pd.read_csv("Resources/institutions.csv")
net_price_df = pd.read_csv("Resources/net-price.csv")
retention_rates_df = pd.read_csv("Resources/retention-rates.csv")

# %%
# Inspect Institutions and clean
institutions_df.head()
# institutions_df.columns.to_list()
# len(institutions_df)
# institutions_df.dtypes
# Out:
#    UnitID                      Institution Name  \
# 0  180203                Aaniiih Nakoda College
# 1  222178          Abilene Christian University
# 2  138558  Abraham Baldwin Agricultural College
# 3  488031            Abraham Lincoln University
# 4  172866                       Academy College
#
#   Institution name alias (HD2016) Street address or post office box (HD2016)  \
# 0                                                269 Blackfeet Avenue Agency
# 1
# 2                            ABAC                             2802 Moore Hwy
# 3                                        3530 Wilshire Boulevard  Suite 1430
# 4                                             1600 W. 82nd Street  Suite 100
#
#   City location of institution (HD2016) State abbreviation (HD2016)  \
# 0                                Harlem                          MT
# 1                               Abilene                          TX
# 2                                Tifton                          GA
# ...

# %%
# look at null values per column
institutions_df.isnull().sum()
# Out:
# UnitID                                                                                             0
# Institution Name                                                                                   0
# Institution name alias (HD2016)                                                                   33
# Street address or post office box (HD2016)                                                        33
# City location of institution (HD2016)                                                             33
# State abbreviation (HD2016)                                                                       33
# ZIP code (HD2016)                                                                                 33
# Institution's internet website address (HD2016)                                                   33
# Longitude location of institution (HD2016)                                                        33
# ...

# %%
columns = ['Institution Name', 'Grand total (EF2016A  All students  Undergraduate total)']
clean_institutions_df = institutions_df.dropna(subset=columns)
clean_institutions_df.head()
len(clean_institutions_df)
# Out:
# 3810

# %%
clean_institutions_df.isnull().sum()
# Out:
# UnitID                                                                                             0
# Institution Name                                                                                   0
# Institution name alias (HD2016)                                                                    0
# Street address or post office box (HD2016)                                                         0
# City location of institution (HD2016)                                                              0
# State abbreviation (HD2016)                                                                        0
# ZIP code (HD2016)                                                                                  0
# Institution's internet website address (HD2016)                                                    0
# Longitude location of institution (HD2016)                                                         0
# ...

# %%
base_columns_df = pd.DataFrame(grad_rates_df[['UnitID',
 'Institution Name',
 'Institution name alias (HD2016)',
 'Street address or post office box (HD2016)',
 'City location of institution (HD2016)',
 'State abbreviation (HD2016)']].dropna())
base_columns_df
# Out:
#       UnitID                      Institution Name  \
# 0     180203                Aaniiih Nakoda College
# 1     222178          Abilene Christian University
# 2     138558  Abraham Baldwin Agricultural College
# 3     488031            Abraham Lincoln University
# 4     172866                       Academy College
# ...      ...                                   ...
# 3838  206695           Youngstown State University
# 3839  375939          YTI Career Institute-Altoona
# 3840  217077             YTI Career Institute-York
# 3841  126119                          Yuba College
# 3842  204255                    Zane State College
#
#      Institution name alias (HD2016)  \
# 0
# 1
# 2                               ABAC
# 3
# 4
# ...                              ...
# 3838
# 3839
# 3840                             YTI
# 3841
# 3842
#
#      Street address or post office box (HD2016)  \
# 0                   269 Blackfeet Avenue Agency
# 1
# ...

# %%
title_2016 = [('UnitID',
              'Institution Name',
              'Institution name alias (HD2016)',
              'Street address or post office box (HD2016)',
              'City location of institution (HD2016)',
              'State abbreviation (HD2016)'
              ,'GR2016')]

grad_rates_2016 = grad_rates_df.filter(regex=title_2016)
grad_rates_2016
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32108/3655041479.py in <module>
#       7               ,'GR2016')]
#       8
# ----> 9 grad_rates_2016 = grad_rates_df.filter(regex=title_2016)
#      10 grad_rates_2016
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in filter(self, items, like, regex, axis)
#    4994                 return matcher.search(ensure_str(x)) is not None
#    4995
# -> 4996             matcher = re.compile(regex)
#    4997             values = labels.map(f)
#    4998             return self.loc(axis=axis)[values]
#
# ~\anaconda3\lib\re.py in compile(pattern, flags)
#     250 def compile(pattern, flags=0):
#     251     "Compile a regular expression pattern, returning a Pattern object."
# --> 252     return _compile(pattern, flags)
#     253
#     254 def purge():
#
# ...

# %%
# inspect grad rates and organize into years
grad_rates_df
# len(grad_rates_df)
grad_rates_df.columns.to_list()
# Out:
# ['UnitID',
#  'Institution Name',
#  'Institution name alias (HD2016)',
#  'Street address or post office box (HD2016)',
#  'City location of institution (HD2016)',
#  'State abbreviation (HD2016)',
#  "Grand total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Completers within 150% of normal time total)",
#  "American Indian or Alaska Native total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Completers within 150% of normal time total)",
#  "Asian total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Completers within 150% of normal time total)",
#  "Black or African American total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Completers within 150% of normal time total)",
#  "Hispanic total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Completers within 150% of normal time total)",
# ...

# %%
clean_grad_rates_2016 = grad_rates_2016.dropna()
clean_grad_rates_2016
# Out:
#       UnitID                     Institution Name  \
# 9     188429                   Adelphi University
# 87    164447       American International College
# 96    449339    American Public University System
# 99    131159                  American University
# 105   150066                  Anderson University
# ...      ...                                  ...
# 3781  206525                Wittenberg University
# 3787  168430           Worcester State University
# 3790  206604  Wright State University-Main Campus
# 3798  130794                      Yale University
# 3834  217059         York College of Pennsylvania
#
#                         Institution name alias (HD2016)  \
# 9
# 87                                                  AIC
# 96    American Military University |American Public ...
# 99
# 105
# ...                                                 ...
# 3781
# 3787
# 3790
# 3798
# 3834                                                YCP
#
# ...

# %%
grad_rates_2016 = grad_rates_df[['UnitID',
 'Institution Name',
 'Institution name alias (HD2016)',
 'Street address or post office box (HD2016)',
 'City location of institution (HD2016)',
 'State abbreviation (HD2016)',
 "Grand total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Completers within 150% of normal time total)",
 "American Indian or Alaska Native total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Completers within 150% of normal time total)",
 "Asian total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Completers within 150% of normal time total)",
 "Black or African American total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Completers within 150% of normal time total)",
 "Hispanic total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Completers within 150% of normal time total)",
 "Native Hawaiian or Other Pacific Islander total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Completers within 150% of normal time total)",
 "White total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Completers within 150% of normal time total)",
 "Race/ethnicity unknown total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Completers within 150% of normal time total)",
 "Two or more races total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Completers within 150% of normal time total)",
 "Nonresident alien total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Completers within 150% of normal time total)",
 "Grand total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Adjusted cohort (revised cohort minus exclusions))",
 "American Indian or Alaska Native total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Adjusted cohort (revised cohort minus exclusions))",
 "Asian total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Adjusted cohort (revised cohort minus exclusions))",
 "Black or African American total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Adjusted cohort (revised cohort minus exclusions))",
 "Hispanic total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Adjusted cohort (revised cohort minus exclusions))",
 "Native Hawaiian or Other Pacific Islander total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Adjusted cohort (revised cohort minus exclusions))",
 "White total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Adjusted cohort (revised cohort minus exclusions))",
 "Race/ethnicity unknown total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Adjusted cohort (revised cohort minus exclusions))",
 "Two or more races total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Adjusted cohort (revised cohort minus exclusions))",
 "Nonresident alien total (GR2016  Bachelor's or equiv subcohort (4-yr institution) Adjusted cohort (revised cohort minus exclusions))",
 "Grand total (GR2016  Bachelor's or equiv subcohort (4-yr institution) CALCULATED GRADUATION RATE)",
 "American Indian or Alaska Native total (GR2016  Bachelor's or equiv subcohort (4-yr institution) CALCULATED GRADUATION RATE)",
 "Asian total (GR2016  Bachelor's or equiv subcohort (4-yr institution) CALCULATED GRADUATION RATE)",
 "Black or African American total (GR2016  Bachelor's or equiv subcohort (4-yr institution) CALCULATED GRADUATION RATE)",
 "Hispanic total (GR2016  Bachelor's or equiv subcohort (4-yr institution) CALCULATED GRADUATION RATE)",
 "Native Hawaiian or Other Pacific Islander total (GR2016  Bachelor's or equiv subcohort (4-yr institution) CALCULATED GRADUATION RATE)",
 "White total (GR2016  Bachelor's or equiv subcohort (4-yr institution) CALCULATED GRADUATION RATE)",
 "Race/ethnicity unknown total (GR2016  Bachelor's or equiv subcohort (4-yr institution) CALCULATED GRADUATION RATE)",
 "Two or more races total (GR2016  Bachelor's or equiv subcohort (4-yr institution) CALCULATED GRADUATION RATE)",
 "Nonresident alien total (GR2016  Bachelor's or equiv subcohort (4-yr institution) CALCULATED GRADUATION RATE)"]]

# %%
grad_rates_2016
# Out:
#       UnitID                      Institution Name  \
# 0     180203                Aaniiih Nakoda College
# 1     222178          Abilene Christian University
# 2     138558  Abraham Baldwin Agricultural College
# 3     488031            Abraham Lincoln University
# 4     172866                       Academy College
# ...      ...                                   ...
# 3838  206695           Youngstown State University
# 3839  375939          YTI Career Institute-Altoona
# 3840  217077             YTI Career Institute-York
# 3841  126119                          Yuba College
# 3842  204255                    Zane State College
#
#      Institution name alias (HD2016)  \
# 0
# 1
# 2                               ABAC
# 3
# 4
# ...                              ...
# 3838
# 3839
# 3840                             YTI
# 3841
# 3842
#
#      Street address or post office box (HD2016)  \
# 0                   269 Blackfeet Avenue Agency
# 1
# ...
